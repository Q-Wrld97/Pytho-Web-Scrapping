# %%
import requests
from csv import writer
from selenium import webdriver
import time
from selenium.webdriver.support import expected_conditions as ec
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import itertools

# %%
#selenium Path
url= 'https://www.footlocker.com/category/mens/shoes.html'
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),)
driver.maximize_window()
driver.get(url)
#time.sleep(3)
clickobj2= driver.find_element(By.ID,'touAgreeBtn')
time.sleep(3)
clickobj2.click()
# Out:
# [WDM] - ====== WebDriver manager ======
# 2022-07-09 22:15:51,493 INFO ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# 2022-07-09 22:15:51,496 INFO Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# 2022-07-09 22:15:51,497 INFO Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [C:\Users\Q\.wdm\drivers\chromedriver\win32\103.0.5060.53\chromedriver.exe] found in cache
# 2022-07-09 22:15:51,584 INFO Driver [C:\Users\Q\.wdm\drivers\chromedriver\win32\103.0.5060.53\chromedriver.exe] found in cache

# %%
#PAGE SCROLLING
# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")
SCROLL_PAUSE_TIME = .5
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, 200);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

clickobj= driver.find_element(By.LINK_TEXT,'Next')
Wname = driver.find_elements(By.CLASS_NAME,'ProductName-primary')
Wprice = driver.find_elements(By.CLASS_NAME,'ProductPrice')

# %%
name = []
price = []
condition = True

while condition:
  #PAGE SCROLLING
  # Get scroll height
  last_height = driver.execute_script("return document.body.scrollHeight")
  SCROLL_PAUSE_TIME = .5
  while True:
      # Scroll down to bottom
      driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
      # Wait to load page
      time.sleep(SCROLL_PAUSE_TIME)
      clickobj= driver.find_element(By.LINK_TEXT,'Next')
      time.sleep(SCROLL_PAUSE_TIME)
      # Calculate new scroll height and compare with last scroll height
      new_height = driver.execute_script("return document.body.scrollHeight")
      if new_height == last_height:
          break
      last_height = new_height
  Wname = driver.find_elements(By.CLASS_NAME,'ProductName-primary')
  Wprice =driver.find_elements(By.CLASS_NAME,'ProductPrice')
  for i in Wname:
    name.append(i.text)
  for i in Wprice:
    price.append(i.text)
  new_list =[]
  with open('Menshoes.csv','a', encoding='utf8',newline='') as f:
    thewriter= writer(f)
    header=['Name','Price','#Color']
    thewriter.writerow(header)
    for n,p in itertools.zip_longest(name,price):
      if n:
          new_list.append(n)
      if p:
          new_list.append(p)
      info = [n,p]
      thewriter.writerow(info)
      print(info)
  clickobj.click()
# Out:
# ['adidas Originals Top Ten Hi', '$100.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['Nike Air Huarache', '$125.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Nike Air Max Plus', '$175.00']
# ['Jordan Retro 1 High OG', '$170.00']
# ["Nike Air More Uptempo '96", '$160.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Nike Air Force 1 Luxe', '$140.00']
# ["Nike Air Force 1 '07 LE", '$110.00']
# ["Nike Air Force 1 '07 LE", '$110.00']
# ['Jordan Retro 1 High OG', '$170.00']
# ['Nike Dunk Hi', '$125.00']
# ['New Balance 550', '$110.00']
# ["Nike Air Force 1 '07 LE Low", '$110.00']
# ['Nike Air Max 270', 'Sale, Price reduced from $160.00 to $129.99\n$129.99$160.00']
# ["Nike Air Force 1 '07", '$110.00']
# ['Nike Air Max 95', 'Sale, Price reduced from $175.00 to $129.99\n$129.99$175.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike KD14', '$150.00']
# ['Jordan AJ 1 Mid SE', '$135.00']
# ['Jordan 6 Rings', '$170.00']
# ['Jordan 6 Rings', '$170.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Crocs Classic Clog x Cereal', '$60.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $120.00 to $84.99\n$84.99$120.00']
# ['Nike VaporMax Plus', '$210.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Max 90', '$140.00']
# ["Nike Air Force 1 Mid '07 LE", '$120.00']
# ['Nike Air Max 95 Essential', '$175.00']
# ['adidas TMAC 3', 'Sale, Price reduced from $130.00 to $84.99\n$84.99$130.00']
# ['Nike Air Max 95', '$175.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $175.00 to $154.99\n$154.99$175.00']
# ['Jordan Legacy 312 Low', '$140.00']
# ['Nike Air Max 97 SE', '$185.00']
# ['Nike Air Max 270', '$160.00']
# ['New Balance 990v5', '$185.00']
# ['New Balance 990v5', '$185.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Crocs Classic Clog x Cereal', '$60.00']
# ['Nike Air Max Plus Terrascape', 'Sale, Price reduced from $185.00 to $149.99\n$149.99$185.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['adidas Originals Top Ten Hi', '$100.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['Nike Air Huarache', '$125.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Nike Air Max Plus', '$175.00']
# ['Jordan Retro 1 High OG', '$170.00']
# ["Nike Air More Uptempo '96", '$160.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Nike Air Force 1 Luxe', '$140.00']
# ["Nike Air Force 1 '07 LE", '$110.00']
# ["Nike Air Force 1 '07 LE", '$110.00']
# ['Jordan Retro 1 High OG', '$170.00']
# ['Nike Dunk Hi', '$125.00']
# ['New Balance 550', '$110.00']
# ["Nike Air Force 1 '07 LE Low", '$110.00']
# ['Nike Air Max 270', 'Sale, Price reduced from $160.00 to $129.99\n$129.99$160.00']
# ["Nike Air Force 1 '07", '$110.00']
# ['Nike Air Max 95', 'Sale, Price reduced from $175.00 to $129.99\n$129.99$175.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike KD14', '$150.00']
# ['Jordan AJ 1 Mid SE', '$135.00']
# ['Jordan 6 Rings', '$170.00']
# ['Jordan 6 Rings', '$170.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Crocs Classic Clog x Cereal', '$60.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $120.00 to $84.99\n$84.99$120.00']
# ['Nike VaporMax Plus', '$210.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Max 90', '$140.00']
# ["Nike Air Force 1 Mid '07 LE", '$120.00']
# ['Nike Air Max 95 Essential', '$175.00']
# ['adidas TMAC 3', 'Sale, Price reduced from $130.00 to $84.99\n$84.99$130.00']
# ['Nike Air Max 95', '$175.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $175.00 to $154.99\n$154.99$175.00']
# ['Jordan Legacy 312 Low', '$140.00']
# ['Nike Air Max 97 SE', '$185.00']
# ['Nike Air Max 270', '$160.00']
# ['New Balance 990v5', '$185.00']
# ['New Balance 990v5', '$185.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Crocs Classic Clog x Cereal', '$60.00']
# ['Nike Air Max Plus Terrascape', 'Sale, Price reduced from $185.00 to $149.99\n$149.99$185.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['Nike Air Max 90', '$130.00']
# ["Nike Air Force 1 '07", '$110.00']
# ['Nike Air Flight Lite Mid', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Jordan 6 Rings', '$170.00']
# ['Nike Kyrie Low 5', '$110.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Kappa Banda Mitel', '$80.00']
# ['PUMA RS-X Rick & Morty', '$120.00']
# ['Nike Air Max 270', '$160.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike Air Presto Mid', 'Sale, Price reduced from $150.00 to $119.99\n$119.99$150.00']
# ['Kappa Banda Mitel', '$80.00']
# ['Nike Air VaporMax 2021 Flyknit', '$210.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $79.99\n$79.99$100.00']
# ['Under Armour Curry 1 Retro', '$130.00']
# ['Nike Air Zoom G.T. Jump', '$180.00']
# ['Timberland 6 Inch Premium Boots', 'Sale, Price reduced from $198.00 to $134.99\n$134.99$198.00']
# ['Nike Blazer High', '$105.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $130.00 to $109.99\n$109.99$130.00']
# ["Nike Air Max '97", 'Sale, Price reduced from $180.00 to $159.99\n$159.99$180.00']
# ['Reebok Club C 85 Vintage', '$85.00']
# ['On Cloudnova', '$150.00']
# ['Nike Air Max Goaterra 2.0', 'Sale, Price reduced from $140.00 to $109.99\n$109.99$140.00']
# ['Nike Air Max Goadome', '$180.00']
# ['On Cloudnova', '$150.00']
# ['Nike Free Run 2', 'Sale, Price reduced from $110.00 to $79.99\n$79.99$110.00']
# ['Nike Air Max 270', '$160.00']
# ['Nike Air Flight Lite Mid', '$130.00']
# ['Jordan Zion 1', 'Sale, Price reduced from $120.00 to $74.99\n$74.99$120.00']
# ['Vans Trek Slip-On', 'Sale, Price reduced from $55.00 to $39.99\n$39.99$55.00']
# ['Kappa Banda Mitel', 'Sale, Price reduced from $80.00 to $59.99\n$59.99$80.00']
# ['Jordan 6-17-23', '$150.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $130.00 to $89.99\n$89.99$130.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Jordan Air Jordan XXXVI', '$185.00']
# ['New Balance Two Wxy', 'Sale, Price reduced from $130.00 to $104.99\n$104.99$130.00']
# ['Jordan Retro 11 Hydro', '$63.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $130.00 to $89.99\n$89.99$130.00']
# ['Nike Air Max 90 Terrascape', '$140.00']
# ["Nike Air Max '97", '$175.00']
# ['Nike Air Max 270', 'Sale, Price reduced from $160.00 to $144.99\n$144.99$160.00']
# ['PUMA Cali Pro', 'Sale, Price reduced from $80.00 to $49.99\n$49.99$80.00']
# ['New Balance 574', '$85.00']
# ['Jordan Stay Loyal', '$110.00']
# ['Jordan AJ 11 Low CMFT', '$125.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $69.99\n$69.99$100.00']
# ["Nike Air Max '97", '$175.00']
# ['Kappa Banda Mitel', '$80.00']
# ['adidas Originals Top Ten Hi', '$100.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['Nike Air Huarache', '$125.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Nike Air Max Plus', '$175.00']
# ['Jordan Retro 1 High OG', '$170.00']
# ["Nike Air More Uptempo '96", '$160.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Nike Air Force 1 Luxe', '$140.00']
# ["Nike Air Force 1 '07 LE", '$110.00']
# ["Nike Air Force 1 '07 LE", '$110.00']
# ['Jordan Retro 1 High OG', '$170.00']
# ['Nike Dunk Hi', '$125.00']
# ['New Balance 550', '$110.00']
# ["Nike Air Force 1 '07 LE Low", '$110.00']
# ['Nike Air Max 270', 'Sale, Price reduced from $160.00 to $129.99\n$129.99$160.00']
# ["Nike Air Force 1 '07", '$110.00']
# ['Nike Air Max 95', 'Sale, Price reduced from $175.00 to $129.99\n$129.99$175.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike KD14', '$150.00']
# ['Jordan AJ 1 Mid SE', '$135.00']
# ['Jordan 6 Rings', '$170.00']
# ['Jordan 6 Rings', '$170.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Crocs Classic Clog x Cereal', '$60.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $120.00 to $84.99\n$84.99$120.00']
# ['Nike VaporMax Plus', '$210.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Max 90', '$140.00']
# ["Nike Air Force 1 Mid '07 LE", '$120.00']
# ['Nike Air Max 95 Essential', '$175.00']
# ['adidas TMAC 3', 'Sale, Price reduced from $130.00 to $84.99\n$84.99$130.00']
# ['Nike Air Max 95', '$175.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $175.00 to $154.99\n$154.99$175.00']
# ['Jordan Legacy 312 Low', '$140.00']
# ['Nike Air Max 97 SE', '$185.00']
# ['Nike Air Max 270', '$160.00']
# ['New Balance 990v5', '$185.00']
# ['New Balance 990v5', '$185.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Crocs Classic Clog x Cereal', '$60.00']
# ['Nike Air Max Plus Terrascape', 'Sale, Price reduced from $185.00 to $149.99\n$149.99$185.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['Nike Air Max 90', '$130.00']
# ["Nike Air Force 1 '07", '$110.00']
# ['Nike Air Flight Lite Mid', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Jordan 6 Rings', '$170.00']
# ['Nike Kyrie Low 5', '$110.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Kappa Banda Mitel', '$80.00']
# ['PUMA RS-X Rick & Morty', '$120.00']
# ['Nike Air Max 270', '$160.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike Air Presto Mid', 'Sale, Price reduced from $150.00 to $119.99\n$119.99$150.00']
# ['Kappa Banda Mitel', '$80.00']
# ['Nike Air VaporMax 2021 Flyknit', '$210.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $79.99\n$79.99$100.00']
# ['Under Armour Curry 1 Retro', '$130.00']
# ['Nike Air Zoom G.T. Jump', '$180.00']
# ['Timberland 6 Inch Premium Boots', 'Sale, Price reduced from $198.00 to $134.99\n$134.99$198.00']
# ['Nike Blazer High', '$105.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $130.00 to $109.99\n$109.99$130.00']
# ["Nike Air Max '97", 'Sale, Price reduced from $180.00 to $159.99\n$159.99$180.00']
# ['Reebok Club C 85 Vintage', '$85.00']
# ['On Cloudnova', '$150.00']
# ['Nike Air Max Goaterra 2.0', 'Sale, Price reduced from $140.00 to $109.99\n$109.99$140.00']
# ['Nike Air Max Goadome', '$180.00']
# ['On Cloudnova', '$150.00']
# ['Nike Free Run 2', 'Sale, Price reduced from $110.00 to $79.99\n$79.99$110.00']
# ['Nike Air Max 270', '$160.00']
# ['Nike Air Flight Lite Mid', '$130.00']
# ['Jordan Zion 1', 'Sale, Price reduced from $120.00 to $74.99\n$74.99$120.00']
# ['Vans Trek Slip-On', 'Sale, Price reduced from $55.00 to $39.99\n$39.99$55.00']
# ['Kappa Banda Mitel', 'Sale, Price reduced from $80.00 to $59.99\n$59.99$80.00']
# ['Jordan 6-17-23', '$150.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $130.00 to $89.99\n$89.99$130.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Jordan Air Jordan XXXVI', '$185.00']
# ['New Balance Two Wxy', 'Sale, Price reduced from $130.00 to $104.99\n$104.99$130.00']
# ['Jordan Retro 11 Hydro', '$63.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $130.00 to $89.99\n$89.99$130.00']
# ['Nike Air Max 90 Terrascape', '$140.00']
# ["Nike Air Max '97", '$175.00']
# ['Nike Air Max 270', 'Sale, Price reduced from $160.00 to $144.99\n$144.99$160.00']
# ['PUMA Cali Pro', 'Sale, Price reduced from $80.00 to $49.99\n$49.99$80.00']
# ['New Balance 574', '$85.00']
# ['Jordan Stay Loyal', '$110.00']
# ['Jordan AJ 11 Low CMFT', '$125.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $69.99\n$69.99$100.00']
# ["Nike Air Max '97", '$175.00']
# ['Kappa Banda Mitel', '$80.00']
# ['Nike KD14', '$150.00']
# ['Nike Air Griffey Max 1', '$170.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $69.99\n$69.99$100.00']
# ['Nike Air Max 90', '$140.00']
# ['Jordan TE 2 Low', '$110.00']
# ['Nike Air Force 1 Boot', '$160.00']
# ['Nike Air Max Terrascape 90', '$140.00']
# ['adidas Originals Ozweego', '$120.00']
# ['Jordan Zoom Separate', 'Sale, Price reduced from $110.00 to $99.99\n$99.99$110.00']
# ['New Balance 574', 'Sale, Price reduced from $85.00 to $59.99\n$59.99$85.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['adidas Trae Young 1', 'Sale, Price reduced from $130.00 to $104.99\n$104.99$130.00']
# ['adidas Ultraboost DNA', '$190.00']
# ['New Balance 574', 'Sale, Price reduced from $85.00 to $59.99\n$59.99$85.00']
# ['Nike Zoom Freak 3', 'Sale, Price reduced from $120.00 to $89.99\n$89.99$120.00']
# ['Nike Air Max Plus', '$175.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $69.99\n$69.99$110.00']
# ['Nike Air Vapormax 2021', '$210.00']
# ['Jordan 6-17-23', '$150.00']
# ['Nike Air VaporMax 2021 Flyknit', '$210.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $159.99\n$159.99$170.00']
# ['adidas Originals Ozweego', '$120.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $84.99\n$84.99$110.00']
# ['Nike Air Max 95 SE', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Reebok Question Mid Anniversary', 'Sale, Price reduced from $160.00 to $129.99\n$129.99$160.00']
# ["Nike Air More Uptempo '96", '$170.00']
# ['Nike Zoom Freak 3', 'Sale, Price reduced from $120.00 to $89.99\n$89.99$120.00']
# ['Nike Air Max 2021', '$160.00']
# ['Crocs Classic Clog', '$50.00']
# ['Nike Zoom Freak 3', 'Sale, Price reduced from $120.00 to $89.99\n$89.99$120.00']
# ['New Balance 574 Core', '$85.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $69.99\n$69.99$100.00']
# ['adidas Originals Top Ten Hi', 'Sale, Price reduced from $90.00 to $69.99\n$69.99$90.00']
# ['Jordan 6-17-23', '$150.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Max Goadome SE', 'Sale, Price reduced from $180.00 to $159.99\n$159.99$180.00']
# ["Nike Air Max '97", '$185.00']
# ['Nike Air Max 90', '$140.00']
# ['Vans Old Skool', 'Sale, Price reduced from $60.00 to $49.99\n$49.99$60.00']
# ['Nike Air Griffey Max 1', '$170.00']
# ['Nike Zoom Freak 3', '$120.00']
# ['Nike Griffey Max 1', '$170.00']
# ['Vans Sk8 Low Color Block', 'Sale, Price reduced from $60.00 to $39.99\n$39.99$60.00']
# ['adidas NMD R1', 'Sale, Price reduced from $140.00 to $109.99\n$109.99$140.00']
# ['adidas Ultraboost 22', 'Sale, Price reduced from $190.00 to $129.99\n$129.99$190.00']
# ['On Cloud X', '$140.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $69.99\n$69.99$110.00']
# ['adidas Originals Top Ten Hi', '$100.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['Nike Air Huarache', '$125.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Nike Air Max Plus', '$175.00']
# ['Jordan Retro 1 High OG', '$170.00']
# ["Nike Air More Uptempo '96", '$160.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Nike Air Force 1 Luxe', '$140.00']
# ["Nike Air Force 1 '07 LE", '$110.00']
# ["Nike Air Force 1 '07 LE", '$110.00']
# ['Jordan Retro 1 High OG', '$170.00']
# ['Nike Dunk Hi', '$125.00']
# ['New Balance 550', '$110.00']
# ["Nike Air Force 1 '07 LE Low", '$110.00']
# ['Nike Air Max 270', 'Sale, Price reduced from $160.00 to $129.99\n$129.99$160.00']
# ["Nike Air Force 1 '07", '$110.00']
# ['Nike Air Max 95', 'Sale, Price reduced from $175.00 to $129.99\n$129.99$175.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike KD14', '$150.00']
# ['Jordan AJ 1 Mid SE', '$135.00']
# ['Jordan 6 Rings', '$170.00']
# ['Jordan 6 Rings', '$170.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Crocs Classic Clog x Cereal', '$60.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $120.00 to $84.99\n$84.99$120.00']
# ['Nike VaporMax Plus', '$210.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Max 90', '$140.00']
# ["Nike Air Force 1 Mid '07 LE", '$120.00']
# ['Nike Air Max 95 Essential', '$175.00']
# ['adidas TMAC 3', 'Sale, Price reduced from $130.00 to $84.99\n$84.99$130.00']
# ['Nike Air Max 95', '$175.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $175.00 to $154.99\n$154.99$175.00']
# ['Jordan Legacy 312 Low', '$140.00']
# ['Nike Air Max 97 SE', '$185.00']
# ['Nike Air Max 270', '$160.00']
# ['New Balance 990v5', '$185.00']
# ['New Balance 990v5', '$185.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Crocs Classic Clog x Cereal', '$60.00']
# ['Nike Air Max Plus Terrascape', 'Sale, Price reduced from $185.00 to $149.99\n$149.99$185.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['Nike Air Max 90', '$130.00']
# ["Nike Air Force 1 '07", '$110.00']
# ['Nike Air Flight Lite Mid', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Jordan 6 Rings', '$170.00']
# ['Nike Kyrie Low 5', '$110.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Kappa Banda Mitel', '$80.00']
# ['PUMA RS-X Rick & Morty', '$120.00']
# ['Nike Air Max 270', '$160.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike Air Presto Mid', 'Sale, Price reduced from $150.00 to $119.99\n$119.99$150.00']
# ['Kappa Banda Mitel', '$80.00']
# ['Nike Air VaporMax 2021 Flyknit', '$210.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $79.99\n$79.99$100.00']
# ['Under Armour Curry 1 Retro', '$130.00']
# ['Nike Air Zoom G.T. Jump', '$180.00']
# ['Timberland 6 Inch Premium Boots', 'Sale, Price reduced from $198.00 to $134.99\n$134.99$198.00']
# ['Nike Blazer High', '$105.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $130.00 to $109.99\n$109.99$130.00']
# ["Nike Air Max '97", 'Sale, Price reduced from $180.00 to $159.99\n$159.99$180.00']
# ['Reebok Club C 85 Vintage', '$85.00']
# ['On Cloudnova', '$150.00']
# ['Nike Air Max Goaterra 2.0', 'Sale, Price reduced from $140.00 to $109.99\n$109.99$140.00']
# ['Nike Air Max Goadome', '$180.00']
# ['On Cloudnova', '$150.00']
# ['Nike Free Run 2', 'Sale, Price reduced from $110.00 to $79.99\n$79.99$110.00']
# ['Nike Air Max 270', '$160.00']
# ['Nike Air Flight Lite Mid', '$130.00']
# ['Jordan Zion 1', 'Sale, Price reduced from $120.00 to $74.99\n$74.99$120.00']
# ['Vans Trek Slip-On', 'Sale, Price reduced from $55.00 to $39.99\n$39.99$55.00']
# ['Kappa Banda Mitel', 'Sale, Price reduced from $80.00 to $59.99\n$59.99$80.00']
# ['Jordan 6-17-23', '$150.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $130.00 to $89.99\n$89.99$130.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Jordan Air Jordan XXXVI', '$185.00']
# ['New Balance Two Wxy', 'Sale, Price reduced from $130.00 to $104.99\n$104.99$130.00']
# ['Jordan Retro 11 Hydro', '$63.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $130.00 to $89.99\n$89.99$130.00']
# ['Nike Air Max 90 Terrascape', '$140.00']
# ["Nike Air Max '97", '$175.00']
# ['Nike Air Max 270', 'Sale, Price reduced from $160.00 to $144.99\n$144.99$160.00']
# ['PUMA Cali Pro', 'Sale, Price reduced from $80.00 to $49.99\n$49.99$80.00']
# ['New Balance 574', '$85.00']
# ['Jordan Stay Loyal', '$110.00']
# ['Jordan AJ 11 Low CMFT', '$125.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $69.99\n$69.99$100.00']
# ["Nike Air Max '97", '$175.00']
# ['Kappa Banda Mitel', '$80.00']
# ['Nike KD14', '$150.00']
# ['Nike Air Griffey Max 1', '$170.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $69.99\n$69.99$100.00']
# ['Nike Air Max 90', '$140.00']
# ['Jordan TE 2 Low', '$110.00']
# ['Nike Air Force 1 Boot', '$160.00']
# ['Nike Air Max Terrascape 90', '$140.00']
# ['adidas Originals Ozweego', '$120.00']
# ['Jordan Zoom Separate', 'Sale, Price reduced from $110.00 to $99.99\n$99.99$110.00']
# ['New Balance 574', 'Sale, Price reduced from $85.00 to $59.99\n$59.99$85.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['adidas Trae Young 1', 'Sale, Price reduced from $130.00 to $104.99\n$104.99$130.00']
# ['adidas Ultraboost DNA', '$190.00']
# ['New Balance 574', 'Sale, Price reduced from $85.00 to $59.99\n$59.99$85.00']
# ['Nike Zoom Freak 3', 'Sale, Price reduced from $120.00 to $89.99\n$89.99$120.00']
# ['Nike Air Max Plus', '$175.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $69.99\n$69.99$110.00']
# ['Nike Air Vapormax 2021', '$210.00']
# ['Jordan 6-17-23', '$150.00']
# ['Nike Air VaporMax 2021 Flyknit', '$210.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $159.99\n$159.99$170.00']
# ['adidas Originals Ozweego', '$120.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $84.99\n$84.99$110.00']
# ['Nike Air Max 95 SE', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Reebok Question Mid Anniversary', 'Sale, Price reduced from $160.00 to $129.99\n$129.99$160.00']
# ["Nike Air More Uptempo '96", '$170.00']
# ['Nike Zoom Freak 3', 'Sale, Price reduced from $120.00 to $89.99\n$89.99$120.00']
# ['Nike Air Max 2021', '$160.00']
# ['Crocs Classic Clog', '$50.00']
# ['Nike Zoom Freak 3', 'Sale, Price reduced from $120.00 to $89.99\n$89.99$120.00']
# ['New Balance 574 Core', '$85.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $69.99\n$69.99$100.00']
# ['adidas Originals Top Ten Hi', 'Sale, Price reduced from $90.00 to $69.99\n$69.99$90.00']
# ['Jordan 6-17-23', '$150.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Max Goadome SE', 'Sale, Price reduced from $180.00 to $159.99\n$159.99$180.00']
# ["Nike Air Max '97", '$185.00']
# ['Nike Air Max 90', '$140.00']
# ['Vans Old Skool', 'Sale, Price reduced from $60.00 to $49.99\n$49.99$60.00']
# ['Nike Air Griffey Max 1', '$170.00']
# ['Nike Zoom Freak 3', '$120.00']
# ['Nike Griffey Max 1', '$170.00']
# ['Vans Sk8 Low Color Block', 'Sale, Price reduced from $60.00 to $39.99\n$39.99$60.00']
# ['adidas NMD R1', 'Sale, Price reduced from $140.00 to $109.99\n$109.99$140.00']
# ['adidas Ultraboost 22', 'Sale, Price reduced from $190.00 to $129.99\n$129.99$190.00']
# ['On Cloud X', '$140.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $69.99\n$69.99$110.00']
# ['New Balance 574', '$85.00']
# ['Nike Burrow', 'Sale, Price reduced from $55.00 to $49.99\n$49.99$55.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Nike LeBron XIX', '$200.00']
# ['adidas Originals Multix', 'Sale, Price reduced from $80.00 to $59.99\n$59.99$80.00']
# ["Reebok Question Mid Class of '16", 'Sale, Price reduced from $150.00 to $119.99\n$119.99$150.00']
# ['Nike Kyrie Low 5', '$110.00']
# ['Nike Air Huarache', '$120.00']
# ['New Balance 327', '$100.00']
# ['Nike Air Total Max Uptempo', '$170.00']
# ['PUMA Suede Classic XXI', 'Sale, Price reduced from $70.00 to $44.99\n$44.99$70.00']
# ['Reebok Club C Vintage', '$85.00']
# ['Nike Air Presto', '$135.00']
# ['adidas Originals Multix', 'Sale, Price reduced from $80.00 to $59.99\n$59.99$80.00']
# ['adidas Ultraboost DNA', 'Sale, Price reduced from $200.00 to $139.99\n$139.99$200.00']
# ['Nike Victori One Slide', 'Sale, Price reduced from $35.00 to $19.99\n$19.99$35.00']
# ['Nike Challenger OG', '$90.00']
# ['Nike Space Hippie 04', 'Sale, Price reduced from $130.00 to $84.99\n$84.99$130.00']
# ['Vans Old Skool', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ["Jordan Flightclub '91", '$130.00']
# ["Reebok Pump Omni Zone II 90's Rules", '$150.00']
# ['Nike Giannis Immortality', '$80.00']
# ["Nike Blazer Mid '77 Jumbo", '$115.00']
# ['Nike Air Force 1 Boot', '$160.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $130.00 to $109.99\n$109.99$130.00']
# ['Nike Air Max Cirro Slide', '$55.00']
# ['Vans Sk8 Hi', 'Sale, Price reduced from $75.00 to $49.99\n$49.99$75.00']
# ['adidas Ultraboost DNA', '$190.00']
# ['Nike Air Flight Lite Mid', '$120.00']
# ['adidas Ultraboost Web DNA', '$190.00']
# ['Timberland 6" Rubber Toe WP Boots', 'Sale, Price reduced from $198.00 to $129.99\n$129.99$198.00']
# ['Crocs Clog All Terrain x Carrots', '$75.00']
# ['Nike Kyrie Infinity', '$130.00']
# ["Nike Air Max '97", '$175.00']
# ['Nike Space Hippie 1', '$130.00']
# ['Nike Air Presto', '$135.00']
# ['New Balance 574 Rugged', 'Sale, Price reduced from $90.00 to $59.99\n$59.99$90.00']
# ['Jordan AJ 11 CMFT Low V2', '$120.00']
# ['Nike Pegasus Trail 3', 'Sale, Price reduced from $160.00 to $154.99\n$154.99$160.00']
# ['Jordan Break Slide', 'Sale, Price reduced from $35.00 to $24.99\n$24.99$35.00']
# ["Nike Blazer Low '77", 'Sale, Price reduced from $100.00 to $79.99\n$79.99$100.00']
# ['Nike Air Presto', 'Sale, Price reduced from $130.00 to $74.99\n$74.99$130.00']
# ['Nike Free Run 2', 'Sale, Price reduced from $110.00 to $99.99\n$99.99$110.00']
# ['New Balance 574', '$85.00']
# ['adidas Originals X_PLR', '$85.00']
# ['Converse All Star High Top', '$65.00']
# ['Jordan Hydro V Premier', '$52.00']
# ['Nike Air Max Plus', '$175.00']
# ['adidas Originals Top Ten Hi', '$100.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['Nike Air Huarache', '$125.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Nike Air Max Plus', '$175.00']
# ['Jordan Retro 1 High OG', '$170.00']
# ["Nike Air More Uptempo '96", '$160.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Nike Air Force 1 Luxe', '$140.00']
# ["Nike Air Force 1 '07 LE", '$110.00']
# ["Nike Air Force 1 '07 LE", '$110.00']
# ['Jordan Retro 1 High OG', '$170.00']
# ['Nike Dunk Hi', '$125.00']
# ['New Balance 550', '$110.00']
# ["Nike Air Force 1 '07 LE Low", '$110.00']
# ['Nike Air Max 270', 'Sale, Price reduced from $160.00 to $129.99\n$129.99$160.00']
# ["Nike Air Force 1 '07", '$110.00']
# ['Nike Air Max 95', 'Sale, Price reduced from $175.00 to $129.99\n$129.99$175.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike KD14', '$150.00']
# ['Jordan AJ 1 Mid SE', '$135.00']
# ['Jordan 6 Rings', '$170.00']
# ['Jordan 6 Rings', '$170.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Crocs Classic Clog x Cereal', '$60.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $120.00 to $84.99\n$84.99$120.00']
# ['Nike VaporMax Plus', '$210.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Max 90', '$140.00']
# ["Nike Air Force 1 Mid '07 LE", '$120.00']
# ['Nike Air Max 95 Essential', '$175.00']
# ['adidas TMAC 3', 'Sale, Price reduced from $130.00 to $84.99\n$84.99$130.00']
# ['Nike Air Max 95', '$175.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $175.00 to $154.99\n$154.99$175.00']
# ['Jordan Legacy 312 Low', '$140.00']
# ['Nike Air Max 97 SE', '$185.00']
# ['Nike Air Max 270', '$160.00']
# ['New Balance 990v5', '$185.00']
# ['New Balance 990v5', '$185.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Crocs Classic Clog x Cereal', '$60.00']
# ['Nike Air Max Plus Terrascape', 'Sale, Price reduced from $185.00 to $149.99\n$149.99$185.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['Nike Air Max 90', '$130.00']
# ["Nike Air Force 1 '07", '$110.00']
# ['Nike Air Flight Lite Mid', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Jordan 6 Rings', '$170.00']
# ['Nike Kyrie Low 5', '$110.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Kappa Banda Mitel', '$80.00']
# ['PUMA RS-X Rick & Morty', '$120.00']
# ['Nike Air Max 270', '$160.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike Air Presto Mid', 'Sale, Price reduced from $150.00 to $119.99\n$119.99$150.00']
# ['Kappa Banda Mitel', '$80.00']
# ['Nike Air VaporMax 2021 Flyknit', '$210.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $79.99\n$79.99$100.00']
# ['Under Armour Curry 1 Retro', '$130.00']
# ['Nike Air Zoom G.T. Jump', '$180.00']
# ['Timberland 6 Inch Premium Boots', 'Sale, Price reduced from $198.00 to $134.99\n$134.99$198.00']
# ['Nike Blazer High', '$105.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $130.00 to $109.99\n$109.99$130.00']
# ["Nike Air Max '97", 'Sale, Price reduced from $180.00 to $159.99\n$159.99$180.00']
# ['Reebok Club C 85 Vintage', '$85.00']
# ['On Cloudnova', '$150.00']
# ['Nike Air Max Goaterra 2.0', 'Sale, Price reduced from $140.00 to $109.99\n$109.99$140.00']
# ['Nike Air Max Goadome', '$180.00']
# ['On Cloudnova', '$150.00']
# ['Nike Free Run 2', 'Sale, Price reduced from $110.00 to $79.99\n$79.99$110.00']
# ['Nike Air Max 270', '$160.00']
# ['Nike Air Flight Lite Mid', '$130.00']
# ['Jordan Zion 1', 'Sale, Price reduced from $120.00 to $74.99\n$74.99$120.00']
# ['Vans Trek Slip-On', 'Sale, Price reduced from $55.00 to $39.99\n$39.99$55.00']
# ['Kappa Banda Mitel', 'Sale, Price reduced from $80.00 to $59.99\n$59.99$80.00']
# ['Jordan 6-17-23', '$150.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $130.00 to $89.99\n$89.99$130.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Jordan Air Jordan XXXVI', '$185.00']
# ['New Balance Two Wxy', 'Sale, Price reduced from $130.00 to $104.99\n$104.99$130.00']
# ['Jordan Retro 11 Hydro', '$63.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $130.00 to $89.99\n$89.99$130.00']
# ['Nike Air Max 90 Terrascape', '$140.00']
# ["Nike Air Max '97", '$175.00']
# ['Nike Air Max 270', 'Sale, Price reduced from $160.00 to $144.99\n$144.99$160.00']
# ['PUMA Cali Pro', 'Sale, Price reduced from $80.00 to $49.99\n$49.99$80.00']
# ['New Balance 574', '$85.00']
# ['Jordan Stay Loyal', '$110.00']
# ['Jordan AJ 11 Low CMFT', '$125.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $69.99\n$69.99$100.00']
# ["Nike Air Max '97", '$175.00']
# ['Kappa Banda Mitel', '$80.00']
# ['Nike KD14', '$150.00']
# ['Nike Air Griffey Max 1', '$170.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $69.99\n$69.99$100.00']
# ['Nike Air Max 90', '$140.00']
# ['Jordan TE 2 Low', '$110.00']
# ['Nike Air Force 1 Boot', '$160.00']
# ['Nike Air Max Terrascape 90', '$140.00']
# ['adidas Originals Ozweego', '$120.00']
# ['Jordan Zoom Separate', 'Sale, Price reduced from $110.00 to $99.99\n$99.99$110.00']
# ['New Balance 574', 'Sale, Price reduced from $85.00 to $59.99\n$59.99$85.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['adidas Trae Young 1', 'Sale, Price reduced from $130.00 to $104.99\n$104.99$130.00']
# ['adidas Ultraboost DNA', '$190.00']
# ['New Balance 574', 'Sale, Price reduced from $85.00 to $59.99\n$59.99$85.00']
# ['Nike Zoom Freak 3', 'Sale, Price reduced from $120.00 to $89.99\n$89.99$120.00']
# ['Nike Air Max Plus', '$175.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $69.99\n$69.99$110.00']
# ['Nike Air Vapormax 2021', '$210.00']
# ['Jordan 6-17-23', '$150.00']
# ['Nike Air VaporMax 2021 Flyknit', '$210.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $159.99\n$159.99$170.00']
# ['adidas Originals Ozweego', '$120.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $84.99\n$84.99$110.00']
# ['Nike Air Max 95 SE', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Reebok Question Mid Anniversary', 'Sale, Price reduced from $160.00 to $129.99\n$129.99$160.00']
# ["Nike Air More Uptempo '96", '$170.00']
# ['Nike Zoom Freak 3', 'Sale, Price reduced from $120.00 to $89.99\n$89.99$120.00']
# ['Nike Air Max 2021', '$160.00']
# ['Crocs Classic Clog', '$50.00']
# ['Nike Zoom Freak 3', 'Sale, Price reduced from $120.00 to $89.99\n$89.99$120.00']
# ['New Balance 574 Core', '$85.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $69.99\n$69.99$100.00']
# ['adidas Originals Top Ten Hi', 'Sale, Price reduced from $90.00 to $69.99\n$69.99$90.00']
# ['Jordan 6-17-23', '$150.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Max Goadome SE', 'Sale, Price reduced from $180.00 to $159.99\n$159.99$180.00']
# ["Nike Air Max '97", '$185.00']
# ['Nike Air Max 90', '$140.00']
# ['Vans Old Skool', 'Sale, Price reduced from $60.00 to $49.99\n$49.99$60.00']
# ['Nike Air Griffey Max 1', '$170.00']
# ['Nike Zoom Freak 3', '$120.00']
# ['Nike Griffey Max 1', '$170.00']
# ['Vans Sk8 Low Color Block', 'Sale, Price reduced from $60.00 to $39.99\n$39.99$60.00']
# ['adidas NMD R1', 'Sale, Price reduced from $140.00 to $109.99\n$109.99$140.00']
# ['adidas Ultraboost 22', 'Sale, Price reduced from $190.00 to $129.99\n$129.99$190.00']
# ['On Cloud X', '$140.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $69.99\n$69.99$110.00']
# ['New Balance 574', '$85.00']
# ['Nike Burrow', 'Sale, Price reduced from $55.00 to $49.99\n$49.99$55.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Nike LeBron XIX', '$200.00']
# ['adidas Originals Multix', 'Sale, Price reduced from $80.00 to $59.99\n$59.99$80.00']
# ["Reebok Question Mid Class of '16", 'Sale, Price reduced from $150.00 to $119.99\n$119.99$150.00']
# ['Nike Kyrie Low 5', '$110.00']
# ['Nike Air Huarache', '$120.00']
# ['New Balance 327', '$100.00']
# ['Nike Air Total Max Uptempo', '$170.00']
# ['PUMA Suede Classic XXI', 'Sale, Price reduced from $70.00 to $44.99\n$44.99$70.00']
# ['Reebok Club C Vintage', '$85.00']
# ['Nike Air Presto', '$135.00']
# ['adidas Originals Multix', 'Sale, Price reduced from $80.00 to $59.99\n$59.99$80.00']
# ['adidas Ultraboost DNA', 'Sale, Price reduced from $200.00 to $139.99\n$139.99$200.00']
# ['Nike Victori One Slide', 'Sale, Price reduced from $35.00 to $19.99\n$19.99$35.00']
# ['Nike Challenger OG', '$90.00']
# ['Nike Space Hippie 04', 'Sale, Price reduced from $130.00 to $84.99\n$84.99$130.00']
# ['Vans Old Skool', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ["Jordan Flightclub '91", '$130.00']
# ["Reebok Pump Omni Zone II 90's Rules", '$150.00']
# ['Nike Giannis Immortality', '$80.00']
# ["Nike Blazer Mid '77 Jumbo", '$115.00']
# ['Nike Air Force 1 Boot', '$160.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $130.00 to $109.99\n$109.99$130.00']
# ['Nike Air Max Cirro Slide', '$55.00']
# ['Vans Sk8 Hi', 'Sale, Price reduced from $75.00 to $49.99\n$49.99$75.00']
# ['adidas Ultraboost DNA', '$190.00']
# ['Nike Air Flight Lite Mid', '$120.00']
# ['adidas Ultraboost Web DNA', '$190.00']
# ['Timberland 6" Rubber Toe WP Boots', 'Sale, Price reduced from $198.00 to $129.99\n$129.99$198.00']
# ['Crocs Clog All Terrain x Carrots', '$75.00']
# ['Nike Kyrie Infinity', '$130.00']
# ["Nike Air Max '97", '$175.00']
# ['Nike Space Hippie 1', '$130.00']
# ['Nike Air Presto', '$135.00']
# ['New Balance 574 Rugged', 'Sale, Price reduced from $90.00 to $59.99\n$59.99$90.00']
# ['Jordan AJ 11 CMFT Low V2', '$120.00']
# ['Nike Pegasus Trail 3', 'Sale, Price reduced from $160.00 to $154.99\n$154.99$160.00']
# ['Jordan Break Slide', 'Sale, Price reduced from $35.00 to $24.99\n$24.99$35.00']
# ["Nike Blazer Low '77", 'Sale, Price reduced from $100.00 to $79.99\n$79.99$100.00']
# ['Nike Air Presto', 'Sale, Price reduced from $130.00 to $74.99\n$74.99$130.00']
# ['Nike Free Run 2', 'Sale, Price reduced from $110.00 to $99.99\n$99.99$110.00']
# ['New Balance 574', '$85.00']
# ['adidas Originals X_PLR', '$85.00']
# ['Converse All Star High Top', '$65.00']
# ['Jordan Hydro V Premier', '$52.00']
# ['Nike Air Max Plus', '$175.00']
# ['New Balance 574', '$85.00']
# ['adidas Originals Ozelia', '$100.00']
# ['Vans SK8 Low', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ['On Cloudnova', '$150.00']
# ['Nike Air Tuned Max', 'Sale, Price reduced from $170.00 to $109.99\n$109.99$170.00']
# ['Nike LeBron XIX', 'Sale, Price reduced from $200.00 to $159.99\n$159.99$200.00']
# ['Nike Free Run 2', 'Sale, Price reduced from $110.00 to $89.99\n$89.99$110.00']
# ['Jordan Why Not Zer0.5', '$130.00']
# ['adidas Ultraboost 22', 'Sale, Price reduced from $190.00 to $179.99\n$179.99$190.00']
# ['Nike GTS 97', '$65.00']
# ["Nike Blazer Mid '77 Jumbo", '$120.00']
# ['Nike Air Huarache', '$125.00']
# ['Under Armour Curry 1 Retro', '$130.00']
# ['Jordan Pro Strong', '$140.00']
# ['adidas D Rose 1.5', '$150.00']
# ['On Cloudnova', '$150.00']
# ['Nike Air More Uptempo', '$160.00']
# ['Jordan Point Lane', '$140.00']
# ['Brooks Ghost 13', 'Sale, Price reduced from $130.00 to $109.99\n$109.99$130.00']
# ['Jordan Stay Loyal', '$110.00']
# ['adidas Ultraboost 5.0 DNA Boost For Breakfast', '$190.00']
# ['Nike Waffle One', '$105.00']
# ['Nike Burrow', 'Sale, Price reduced from $55.00 to $34.99\n$34.99$55.00']
# ['Nike LeBron XIX', '$200.00']
# ['Vans Old Skool', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ['Nike Challenger OG', 'Sale, Price reduced from $90.00 to $79.99\n$79.99$90.00']
# ['Jordan Air Jordan XXXVI Low', '$165.00']
# ["Nike Air Max '97", '$180.00']
# ['adidas Trae Young 1', 'Sale, Price reduced from $140.00 to $99.99\n$99.99$140.00']
# ['Nike Air Max Cirro Slide', '$55.00']
# ['Nike Air Max Pre-Day', '$140.00']
# ['Nike Kyrie Infinity', '$130.00']
# ['Reebok Classic Nylon', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['adidas Originals NMD R1 Kenny', '$160.00']
# ['adidas Originals NMD R1.V2', 'Sale, Price reduced from $140.00 to $119.99\n$119.99$140.00']
# ["Nike Air Max '97", '$175.00']
# ['Vans Old Skool', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ["Nike Free Run 5.0 '21", '$100.00']
# ['Jordan Zion 1', '$120.00']
# ['Jordan 6 Rings', '$170.00']
# ['PUMA Clyde All-Pro Kuzma Mid', 'Sale, Price reduced from $150.00 to $109.99\n$109.99$150.00']
# ["Nike Blazer Mid '77", '$100.00']
# ['adidas Trae Young 1', 'Sale, Price reduced from $130.00 to $104.99\n$104.99$130.00']
# ['Nike Victori One Slide', '$35.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $120.00 to $109.99\n$109.99$120.00']
# ['PUMA RS-X Dazed', '$110.00']
# ['Jordan Point Lane', '$140.00']
# ['adidas Originals Top Ten Hi', '$100.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['Nike Air Huarache', '$125.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Nike Air Max Plus', '$175.00']
# ['Jordan Retro 1 High OG', '$170.00']
# ["Nike Air More Uptempo '96", '$160.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Nike Air Force 1 Luxe', '$140.00']
# ["Nike Air Force 1 '07 LE", '$110.00']
# ["Nike Air Force 1 '07 LE", '$110.00']
# ['Jordan Retro 1 High OG', '$170.00']
# ['Nike Dunk Hi', '$125.00']
# ['New Balance 550', '$110.00']
# ["Nike Air Force 1 '07 LE Low", '$110.00']
# ['Nike Air Max 270', 'Sale, Price reduced from $160.00 to $129.99\n$129.99$160.00']
# ["Nike Air Force 1 '07", '$110.00']
# ['Nike Air Max 95', 'Sale, Price reduced from $175.00 to $129.99\n$129.99$175.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike KD14', '$150.00']
# ['Jordan AJ 1 Mid SE', '$135.00']
# ['Jordan 6 Rings', '$170.00']
# ['Jordan 6 Rings', '$170.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Crocs Classic Clog x Cereal', '$60.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $120.00 to $84.99\n$84.99$120.00']
# ['Nike VaporMax Plus', '$210.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Max 90', '$140.00']
# ["Nike Air Force 1 Mid '07 LE", '$120.00']
# ['Nike Air Max 95 Essential', '$175.00']
# ['adidas TMAC 3', 'Sale, Price reduced from $130.00 to $84.99\n$84.99$130.00']
# ['Nike Air Max 95', '$175.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $175.00 to $154.99\n$154.99$175.00']
# ['Jordan Legacy 312 Low', '$140.00']
# ['Nike Air Max 97 SE', '$185.00']
# ['Nike Air Max 270', '$160.00']
# ['New Balance 990v5', '$185.00']
# ['New Balance 990v5', '$185.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Crocs Classic Clog x Cereal', '$60.00']
# ['Nike Air Max Plus Terrascape', 'Sale, Price reduced from $185.00 to $149.99\n$149.99$185.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['Nike Air Max 90', '$130.00']
# ["Nike Air Force 1 '07", '$110.00']
# ['Nike Air Flight Lite Mid', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Jordan 6 Rings', '$170.00']
# ['Nike Kyrie Low 5', '$110.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['Kappa Banda Mitel', '$80.00']
# ['PUMA RS-X Rick & Morty', '$120.00']
# ['Nike Air Max 270', '$160.00']
# ['Nike Air Max 90', '$130.00']
# ['Nike Air Presto Mid', 'Sale, Price reduced from $150.00 to $119.99\n$119.99$150.00']
# ['Kappa Banda Mitel', '$80.00']
# ['Nike Air VaporMax 2021 Flyknit', '$210.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $79.99\n$79.99$100.00']
# ['Under Armour Curry 1 Retro', '$130.00']
# ['Nike Air Zoom G.T. Jump', '$180.00']
# ['Timberland 6 Inch Premium Boots', 'Sale, Price reduced from $198.00 to $134.99\n$134.99$198.00']
# ['Nike Blazer High', '$105.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $130.00 to $109.99\n$109.99$130.00']
# ["Nike Air Max '97", 'Sale, Price reduced from $180.00 to $159.99\n$159.99$180.00']
# ['Reebok Club C 85 Vintage', '$85.00']
# ['On Cloudnova', '$150.00']
# ['Nike Air Max Goaterra 2.0', 'Sale, Price reduced from $140.00 to $109.99\n$109.99$140.00']
# ['Nike Air Max Goadome', '$180.00']
# ['On Cloudnova', '$150.00']
# ['Nike Free Run 2', 'Sale, Price reduced from $110.00 to $79.99\n$79.99$110.00']
# ['Nike Air Max 270', '$160.00']
# ['Nike Air Flight Lite Mid', '$130.00']
# ['Jordan Zion 1', 'Sale, Price reduced from $120.00 to $74.99\n$74.99$120.00']
# ['Vans Trek Slip-On', 'Sale, Price reduced from $55.00 to $39.99\n$39.99$55.00']
# ['Kappa Banda Mitel', 'Sale, Price reduced from $80.00 to $59.99\n$59.99$80.00']
# ['Jordan 6-17-23', '$150.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $130.00 to $89.99\n$89.99$130.00']
# ["Jordan Flightclub '91", '$130.00']
# ['Jordan Air Jordan XXXVI', '$185.00']
# ['New Balance Two Wxy', 'Sale, Price reduced from $130.00 to $104.99\n$104.99$130.00']
# ['Jordan Retro 11 Hydro', '$63.00']
# ['Nike Air Zoom Pegasus 38', 'Sale, Price reduced from $130.00 to $89.99\n$89.99$130.00']
# ['Nike Air Max 90 Terrascape', '$140.00']
# ["Nike Air Max '97", '$175.00']
# ['Nike Air Max 270', 'Sale, Price reduced from $160.00 to $144.99\n$144.99$160.00']
# ['PUMA Cali Pro', 'Sale, Price reduced from $80.00 to $49.99\n$49.99$80.00']
# ['New Balance 574', '$85.00']
# ['Jordan Stay Loyal', '$110.00']
# ['Jordan AJ 11 Low CMFT', '$125.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $69.99\n$69.99$100.00']
# ["Nike Air Max '97", '$175.00']
# ['Kappa Banda Mitel', '$80.00']
# ['Nike KD14', '$150.00']
# ['Nike Air Griffey Max 1', '$170.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $69.99\n$69.99$100.00']
# ['Nike Air Max 90', '$140.00']
# ['Jordan TE 2 Low', '$110.00']
# ['Nike Air Force 1 Boot', '$160.00']
# ['Nike Air Max Terrascape 90', '$140.00']
# ['adidas Originals Ozweego', '$120.00']
# ['Jordan Zoom Separate', 'Sale, Price reduced from $110.00 to $99.99\n$99.99$110.00']
# ['New Balance 574', 'Sale, Price reduced from $85.00 to $59.99\n$59.99$85.00']
# ['Nike Air Vapormax Plus', '$210.00']
# ['adidas Trae Young 1', 'Sale, Price reduced from $130.00 to $104.99\n$104.99$130.00']
# ['adidas Ultraboost DNA', '$190.00']
# ['New Balance 574', 'Sale, Price reduced from $85.00 to $59.99\n$59.99$85.00']
# ['Nike Zoom Freak 3', 'Sale, Price reduced from $120.00 to $89.99\n$89.99$120.00']
# ['Nike Air Max Plus', '$175.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $69.99\n$69.99$110.00']
# ['Nike Air Vapormax 2021', '$210.00']
# ['Jordan 6-17-23', '$150.00']
# ['Nike Air VaporMax 2021 Flyknit', '$210.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Nike Air Max Plus', 'Sale, Price reduced from $170.00 to $159.99\n$159.99$170.00']
# ['adidas Originals Ozweego', '$120.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $84.99\n$84.99$110.00']
# ['Nike Air Max 95 SE', 'Sale, Price reduced from $170.00 to $149.99\n$149.99$170.00']
# ['Reebok Question Mid Anniversary', 'Sale, Price reduced from $160.00 to $129.99\n$129.99$160.00']
# ["Nike Air More Uptempo '96", '$170.00']
# ['Nike Zoom Freak 3', 'Sale, Price reduced from $120.00 to $89.99\n$89.99$120.00']
# ['Nike Air Max 2021', '$160.00']
# ['Crocs Classic Clog', '$50.00']
# ['Nike Zoom Freak 3', 'Sale, Price reduced from $120.00 to $89.99\n$89.99$120.00']
# ['New Balance 574 Core', '$85.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $69.99\n$69.99$100.00']
# ['adidas Originals Top Ten Hi', 'Sale, Price reduced from $90.00 to $69.99\n$69.99$90.00']
# ['Jordan 6-17-23', '$150.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Air Max Goadome SE', 'Sale, Price reduced from $180.00 to $159.99\n$159.99$180.00']
# ["Nike Air Max '97", '$185.00']
# ['Nike Air Max 90', '$140.00']
# ['Vans Old Skool', 'Sale, Price reduced from $60.00 to $49.99\n$49.99$60.00']
# ['Nike Air Griffey Max 1', '$170.00']
# ['Nike Zoom Freak 3', '$120.00']
# ['Nike Griffey Max 1', '$170.00']
# ['Vans Sk8 Low Color Block', 'Sale, Price reduced from $60.00 to $39.99\n$39.99$60.00']
# ['adidas NMD R1', 'Sale, Price reduced from $140.00 to $109.99\n$109.99$140.00']
# ['adidas Ultraboost 22', 'Sale, Price reduced from $190.00 to $129.99\n$129.99$190.00']
# ['On Cloud X', '$140.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $69.99\n$69.99$110.00']
# ['New Balance 574', '$85.00']
# ['Nike Burrow', 'Sale, Price reduced from $55.00 to $49.99\n$49.99$55.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $120.00 to $99.99\n$99.99$120.00']
# ['Nike LeBron XIX', '$200.00']
# ['adidas Originals Multix', 'Sale, Price reduced from $80.00 to $59.99\n$59.99$80.00']
# ["Reebok Question Mid Class of '16", 'Sale, Price reduced from $150.00 to $119.99\n$119.99$150.00']
# ['Nike Kyrie Low 5', '$110.00']
# ['Nike Air Huarache', '$120.00']
# ['New Balance 327', '$100.00']
# ['Nike Air Total Max Uptempo', '$170.00']
# ['PUMA Suede Classic XXI', 'Sale, Price reduced from $70.00 to $44.99\n$44.99$70.00']
# ['Reebok Club C Vintage', '$85.00']
# ['Nike Air Presto', '$135.00']
# ['adidas Originals Multix', 'Sale, Price reduced from $80.00 to $59.99\n$59.99$80.00']
# ['adidas Ultraboost DNA', 'Sale, Price reduced from $200.00 to $139.99\n$139.99$200.00']
# ['Nike Victori One Slide', 'Sale, Price reduced from $35.00 to $19.99\n$19.99$35.00']
# ['Nike Challenger OG', '$90.00']
# ['Nike Space Hippie 04', 'Sale, Price reduced from $130.00 to $84.99\n$84.99$130.00']
# ['Vans Old Skool', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ["Jordan Flightclub '91", '$130.00']
# ["Reebok Pump Omni Zone II 90's Rules", '$150.00']
# ['Nike Giannis Immortality', '$80.00']
# ["Nike Blazer Mid '77 Jumbo", '$115.00']
# ['Nike Air Force 1 Boot', '$160.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $130.00 to $109.99\n$109.99$130.00']
# ['Nike Air Max Cirro Slide', '$55.00']
# ['Vans Sk8 Hi', 'Sale, Price reduced from $75.00 to $49.99\n$49.99$75.00']
# ['adidas Ultraboost DNA', '$190.00']
# ['Nike Air Flight Lite Mid', '$120.00']
# ['adidas Ultraboost Web DNA', '$190.00']
# ['Timberland 6" Rubber Toe WP Boots', 'Sale, Price reduced from $198.00 to $129.99\n$129.99$198.00']
# ['Crocs Clog All Terrain x Carrots', '$75.00']
# ['Nike Kyrie Infinity', '$130.00']
# ["Nike Air Max '97", '$175.00']
# ['Nike Space Hippie 1', '$130.00']
# ['Nike Air Presto', '$135.00']
# ['New Balance 574 Rugged', 'Sale, Price reduced from $90.00 to $59.99\n$59.99$90.00']
# ['Jordan AJ 11 CMFT Low V2', '$120.00']
# ['Nike Pegasus Trail 3', 'Sale, Price reduced from $160.00 to $154.99\n$154.99$160.00']
# ['Jordan Break Slide', 'Sale, Price reduced from $35.00 to $24.99\n$24.99$35.00']
# ["Nike Blazer Low '77", 'Sale, Price reduced from $100.00 to $79.99\n$79.99$100.00']
# ['Nike Air Presto', 'Sale, Price reduced from $130.00 to $74.99\n$74.99$130.00']
# ['Nike Free Run 2', 'Sale, Price reduced from $110.00 to $99.99\n$99.99$110.00']
# ['New Balance 574', '$85.00']
# ['adidas Originals X_PLR', '$85.00']
# ['Converse All Star High Top', '$65.00']
# ['Jordan Hydro V Premier', '$52.00']
# ['Nike Air Max Plus', '$175.00']
# ['New Balance 574', '$85.00']
# ['adidas Originals Ozelia', '$100.00']
# ['Vans SK8 Low', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ['On Cloudnova', '$150.00']
# ['Nike Air Tuned Max', 'Sale, Price reduced from $170.00 to $109.99\n$109.99$170.00']
# ['Nike LeBron XIX', 'Sale, Price reduced from $200.00 to $159.99\n$159.99$200.00']
# ['Nike Free Run 2', 'Sale, Price reduced from $110.00 to $89.99\n$89.99$110.00']
# ['Jordan Why Not Zer0.5', '$130.00']
# ['adidas Ultraboost 22', 'Sale, Price reduced from $190.00 to $179.99\n$179.99$190.00']
# ['Nike GTS 97', '$65.00']
# ["Nike Blazer Mid '77 Jumbo", '$120.00']
# ['Nike Air Huarache', '$125.00']
# ['Under Armour Curry 1 Retro', '$130.00']
# ['Jordan Pro Strong', '$140.00']
# ['adidas D Rose 1.5', '$150.00']
# ['On Cloudnova', '$150.00']
# ['Nike Air More Uptempo', '$160.00']
# ['Jordan Point Lane', '$140.00']
# ...
# ['Nike Air Max Plus', '$175.00']
# ['New Balance 574', '$85.00']
# ['adidas Originals Ozelia', '$100.00']
# ['Vans SK8 Low', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ['On Cloudnova', '$150.00']
# ['Nike Air Tuned Max', 'Sale, Price reduced from $170.00 to $109.99\n$109.99$170.00']
# ['Nike LeBron XIX', 'Sale, Price reduced from $200.00 to $159.99\n$159.99$200.00']
# ['Nike Free Run 2', 'Sale, Price reduced from $110.00 to $89.99\n$89.99$110.00']
# ['Jordan Why Not Zer0.5', '$130.00']
# ['adidas Ultraboost 22', 'Sale, Price reduced from $190.00 to $179.99\n$179.99$190.00']
# ['Nike GTS 97', '$65.00']
# ["Nike Blazer Mid '77 Jumbo", '$120.00']
# ['Nike Air Huarache', '$125.00']
# ['Under Armour Curry 1 Retro', '$130.00']
# ['Jordan Pro Strong', '$140.00']
# ['adidas D Rose 1.5', '$150.00']
# ['On Cloudnova', '$150.00']
# ['Nike Air More Uptempo', '$160.00']
# ['Jordan Point Lane', '$140.00']
# ['Brooks Ghost 13', 'Sale, Price reduced from $130.00 to $109.99\n$109.99$130.00']
# ['Jordan Stay Loyal', '$110.00']
# ['adidas Ultraboost 5.0 DNA Boost For Breakfast', '$190.00']
# ['Nike Waffle One', '$105.00']
# ['Nike Burrow', 'Sale, Price reduced from $55.00 to $34.99\n$34.99$55.00']
# ['Nike LeBron XIX', '$200.00']
# ['Vans Old Skool', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ['Nike Challenger OG', 'Sale, Price reduced from $90.00 to $79.99\n$79.99$90.00']
# ['Jordan Air Jordan XXXVI Low', '$165.00']
# ["Nike Air Max '97", '$180.00']
# ['adidas Trae Young 1', 'Sale, Price reduced from $140.00 to $99.99\n$99.99$140.00']
# ['Nike Air Max Cirro Slide', '$55.00']
# ['Nike Air Max Pre-Day', '$140.00']
# ['Nike Kyrie Infinity', '$130.00']
# ['Reebok Classic Nylon', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ["Nike Air Force 1 '07 LV8", '$120.00']
# ['adidas Originals NMD R1 Kenny', '$160.00']
# ['adidas Originals NMD R1.V2', 'Sale, Price reduced from $140.00 to $119.99\n$119.99$140.00']
# ["Nike Air Max '97", '$175.00']
# ['Vans Old Skool', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ["Nike Free Run 5.0 '21", '$100.00']
# ['Jordan Zion 1', '$120.00']
# ['Jordan 6 Rings', '$170.00']
# ['PUMA Clyde All-Pro Kuzma Mid', 'Sale, Price reduced from $150.00 to $109.99\n$109.99$150.00']
# ["Nike Blazer Mid '77", '$100.00']
# ['adidas Trae Young 1', 'Sale, Price reduced from $130.00 to $104.99\n$104.99$130.00']
# ['Nike Victori One Slide', '$35.00']
# ['Nike Air Huarache', 'Sale, Price reduced from $120.00 to $109.99\n$109.99$120.00']
# ['PUMA RS-X Dazed', '$110.00']
# ['Jordan Point Lane', '$140.00']
# ['New Balance 990v5', '$185.00']
# ['Vans Sk8 Hi', 'Sale, Price reduced from $70.00 to $49.99\n$49.99$70.00']
# ['Nike Zoom Freak 3', '$120.00']
# ['adidas Originals Swift Run', '$90.00']
# ['Fila Grant Hill 2 25th Anniversary', 'Sale, Price reduced from $150.00 to $104.99\n$104.99$150.00']
# ["Nike Air Max '97", 'Sale, Price reduced from $185.00 to $179.99\n$179.99$185.00']
# ["Nike Blazer Mid '77", '$105.00']
# ['New Balance 992', 'Sale, Price reduced from $185.00 to $129.99\n$129.99$185.00']
# ['Nike Kyrie Infinity', '$130.00']
# ['adidas Ultraboost DNA 5.0', '$190.00']
# ['New Balance 574', 'Sale, Price reduced from $80.00 to $59.99\n$59.99$80.00']
# ['Nike Free Run 2', 'Sale, Price reduced from $110.00 to $69.99\n$69.99$110.00']
# ['adidas Ultraboost 1.0 DNA', '$190.00']
# ['New Balance 574 Rugged', '$90.00']
# ['Timberland 6" Premium Waterproof Boots', '$210.00']
# ['Jordan AJ XXXVI', '$185.00']
# ['Nike Pegasus Trail 3', 'Sale, Price reduced from $160.00 to $149.99\n$149.99$160.00']
# ['New Balance 574 Classic', '$80.00']
# ['Brooks Revel 4', 'Sale, Price reduced from $100.00 to $64.99\n$64.99$100.00']
# ['Nike Air Max Plus SE', 'Sale, Price reduced from $170.00 to $159.99\n$159.99$170.00']
# ['Nike LeBron XIX', '$200.00']
# ['adidas Originals Superstar', '$100.00']
# ['PUMA Suede Classic XXI', 'Sale, Price reduced from $70.00 to $49.99\n$49.99$70.00']
# ['Vans Trek Slip-On', 'Sale, Price reduced from $55.00 to $34.99\n$34.99$55.00']
# ['Converse UNT1TL3D High Top', '$75.00']
# ['Nike Air Max Plus', '$175.00']
# ['Nike Kyrie Infinity', '$130.00']
# ['ASICS® GEL-Cumulus 23', 'Sale, Price reduced from $120.00 to $79.99\n$79.99$120.00']
# ['Crocs Classic Clog', 'Sale, Price reduced from $60.00 to $29.99\n$29.99$60.00']
# ['Nike Air Presto', 'Sale, Price reduced from $150.00 to $119.99\n$119.99$150.00']
# ['Nike Space Hippie 04', 'Sale, Price reduced from $130.00 to $119.99\n$119.99$130.00']
# ['Jordan Break Slide', '$35.00']
# ['adidas Originals Multix', 'Sale, Price reduced from $80.00 to $59.99\n$59.99$80.00']
# ['Vans Old Skool', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ['Jordan Zoom Separate', '$110.00']
# ['Jordan Series Mid', '$90.00']
# ['Jordan 6-17-23', '$150.00']
# ['adidas Originals Top Ten Hi', '$90.00']
# ['PUMA RS-X3 Render', 'Sale, Price reduced from $110.00 to $84.99\n$84.99$110.00']
# ['New Balance 327', 'Sale, Price reduced from $100.00 to $59.99\n$59.99$100.00']
# ['Reebok Shaqnosis Damenosis x Adidas', 'Sale, Price reduced from $150.00 to $94.99\n$94.99$150.00']
# ['Crocs Classic Clog', '$50.00']
# ['Nike Air Max Plus Terrascape', '$185.00']
# ['Jordan AJ XXXVI', '$185.00']
# ['adidas Adissage Slide', 'Sale, Price reduced from $30.00 to $19.99\n$19.99$30.00']
# ['Nike Zoom Freak 3', '$120.00']
# ['Vans Old Skool', '$70.00']
# ['Nike Space Hippie', '$130.00']
# ['Reebok Club C Revenge VTG', '$85.00']
# ['Jordan Why Not Zer0.5', '$130.00']
# ['Nike KD14', 'Sale, Price reduced from $150.00 to $104.99\n$104.99$150.00']
# ['Reebok Pump Omni', '$160.00']
# ['Nike Zoom Freak 3', 'Sale, Price reduced from $120.00 to $84.99\n$84.99$120.00']
# ['Vans SK8 Low', 'Sale, Price reduced from $65.00 to $44.99\n$44.99$65.00']
# ['Nike Space Hippie 04', 'Sale, Price reduced from $130.00 to $79.99\n$79.99$130.00']
# ['Converse All Star Low Top', '$60.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $74.99\n$74.99$110.00']
# ['adidas Ozweego', '$120.00']
# ['Nike Challenger OG', 'Sale, Price reduced from $90.00 to $69.99\n$69.99$90.00']
# ['Nike Asuna 2 Slide', '$50.00']
# ['Crocs Classic Clog', '$50.00']
# ['Nike Canyon Sandal', 'Sale, Price reduced from $75.00 to $59.99\n$59.99$75.00']
# ['Jordan Zoom Separate', 'Sale, Price reduced from $110.00 to $99.99\n$99.99$110.00']
# ['Nike GTS 97', '$70.00']
# ['Nike Air Huarache', '$125.00']
# ['Reebok Classic Leather Nylon', 'Sale, Price reduced from $65.00 to $54.99\n$54.99$65.00']
# ['Nike Air Presto', 'Sale, Price reduced from $130.00 to $104.99\n$104.99$130.00']
# ['adidas Originals Swift Run', '$90.00']
# ['adidas Ultraboost DNA', '$190.00']
# ['Nike Waffle 1', 'Sale, Price reduced from $110.00 to $89.99\n$89.99$110.00']
# ['Reebok Kamikaze Mid', 'Sale, Price reduced from $120.00 to $89.99\n$89.99$120.00']
# ['Vans Slip On Parisian Night', 'Sale, Price reduced from $60.00 to $39.99\n$39.99$60.00']
# ['New Balance 5740 V1', '$120.00']
# ['New Balance 574 Rugged', 'Sale, Price reduced from $90.00 to $59.99\n$59.99$90.00']
# ['Diadora N9002', 'Sale, Price reduced from $120.00 to $94.99\n$94.99$120.00']
# ['Vans Classic Slip On', '$60.00']
# ['Nike Air Max Plus F2', '$185.00']
# ["Nike Blazer Mid '77", '$100.00']
# ['Nike Air Max 2021', '$160.00']
# ['New Balance 327', '$100.00']
# ['adidas Originals Top Ten Hi', 'Sale, Price reduced from $90.00 to $79.99\n$79.99$90.00']
# ['Nike Air Vapormax 21 FK', '$210.00']
# ['New Balance 990 V3', '$185.00']
# ['Nike Air Max 2021', '$160.00']
# ['Brooks Ghost 14', '$140.00']
# ['adidas Originals NMD R1.V2', '$140.00']
# ['adidas Originals Top Ten HI', 'Sale, Price reduced from $90.00 to $79.99\n$79.99$90.00']
# ['adidas Originals Superstar', 'Sale, Price reduced from $90.00 to $54.99\n$54.99$90.00']
# ['Nike Air Presto', 'Sale, Price reduced from $130.00 to $104.99\n$104.99$130.00']
# ['adidas Dame 7 EXTPLY', 'Sale, Price reduced from $110.00 to $79.99\n$79.99$110.00']
# ['adidas Harden Vol 6', '$140.00']
# ['Jordan Point Lane', '$140.00']
# ['adidas Originals Superstar', '$95.00']
# ['New Balance M5740 V1', 'Sale, Price reduced from $110.00 to $69.99\n$69.99$110.00']
# ['PUMA RS-X', 'Sale, Price reduced from $110.00 to $89.99\n$89.99$110.00']
# ['Birkenstock Arizona Cork Sandals', '$110.00']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Untitled-1.ipynb Cell 4 in <cell line: 5>()
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=22'>23</a> Wprice =driver.find_elements(By.CLASS_NAME,'ProductPrice')
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=23'>24</a> for i in Wname:
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=24'>25</a>   name.append(i.text)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=25'>26</a> for i in Wprice:
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=26'>27</a>   price.append(i.text)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\webelement.py:84, in WebElement.text(self)
#      81 @property
#      82 def text(self) -> str:
#      83     """The text of the element."""
# ---> 84     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\webdriver.py:433, in WebDriver.execute(self, driver_command, params)
#     430         params['sessionId'] = self.session_id
#     432 params = self._wrap_value(params)
# --> 433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
#     435     self.error_handler.check_response(response)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\remote_connection.py:344, in RemoteConnection.execute(self, command, params)
#     342 data = utils.dump_json(params)
#     343 url = f"{self._url}{path}"
# --> 344 return self._request(command_info[0], url, body=data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\remote_connection.py:366, in RemoteConnection._request(self, method, url, body)
#     363     body = None
#     365 if self.keep_alive:
# --> 366     response = self._conn.request(method, url, body=body, headers=headers)
#     367     statuscode = response.status
#     368 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\request.py:74, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      71 urlopen_kw["request_url"] = url
#      73 if method in self._encode_url_methods:
# ---> 74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
#      78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\request.py:96, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      93 if fields:
#      94     url += "?" + urlencode(fields)
# ---> 96 return self.urlopen(method, url, **extra_kw)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.1520.0_x64__qbz5n2kfra8p0\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.1520.0_x64__qbz5n2kfra8p0\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.1520.0_x64__qbz5n2kfra8p0\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.1520.0_x64__qbz5n2kfra8p0\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:
